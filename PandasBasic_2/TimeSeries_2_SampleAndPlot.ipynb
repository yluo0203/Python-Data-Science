# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import datetime

# %%
t_range = pd.date_range("2016-10-01", "2016-12-31")
t_range
# Out:
# DatetimeIndex(['2016-10-01', '2016-10-02', '2016-10-03', '2016-10-04',
#                '2016-10-05', '2016-10-06', '2016-10-07', '2016-10-08',
#                '2016-10-09', '2016-10-10', '2016-10-11', '2016-10-12',
#                '2016-10-13', '2016-10-14', '2016-10-15', '2016-10-16',
#                '2016-10-17', '2016-10-18', '2016-10-19', '2016-10-20',
#                '2016-10-21', '2016-10-22', '2016-10-23', '2016-10-24',
#                '2016-10-25', '2016-10-26', '2016-10-27', '2016-10-28',
#                '2016-10-29', '2016-10-30', '2016-10-31', '2016-11-01',
#                '2016-11-02', '2016-11-03', '2016-11-04', '2016-11-05',
#                '2016-11-06', '2016-11-07', '2016-11-08', '2016-11-09',
#                '2016-11-10', '2016-11-11', '2016-11-12', '2016-11-13',
#                '2016-11-14', '2016-11-15', '2016-11-16', '2016-11-17',
#                '2016-11-18', '2016-11-19', '2016-11-20', '2016-11-21',
# ...

# %%
s = Series(np.random.rand(len(t_range)), index = t_range)
s
# Out:
# 2016-10-01    0.164638
# 2016-10-02    0.374435
# 2016-10-03    0.476870
# 2016-10-04    0.379307
# 2016-10-05    0.225576
# 2016-10-06    0.645746
# 2016-10-07    0.121945
# 2016-10-08    0.628021
# 2016-10-09    0.820631
# 2016-10-10    0.336651
# 2016-10-11    0.380865
# 2016-10-12    0.589434
# 2016-10-13    0.094487
# 2016-10-14    0.450079
# 2016-10-15    0.399033
# 2016-10-16    0.787507
# 2016-10-17    0.526750
# 2016-10-18    0.342054
# 2016-10-19    0.150808
# 2016-10-20    0.916632
# 2016-10-21    0.518617
# 2016-10-22    0.039260
# 2016-10-23    0.709168
# 2016-10-24    0.424110
# 2016-10-25    0.939991
# 2016-10-26    0.820521
# 2016-10-27    0.900590
# 2016-10-28    0.277990
# 2016-10-29    0.781752
# 2016-10-30    0.978119
#                 ...
# 2016-12-02    0.863218
# 2016-12-03    0.868398
# 2016-12-04    0.622651
# 2016-12-05    0.775055
# 2016-12-06    0.438470
# 2016-12-07    0.748867
# 2016-12-08    0.922156
# 2016-12-09    0.024494
# 2016-12-10    0.877806
# ...

# %%
s["2016-11"]
# Out:
# 2016-11-01    0.813806
# 2016-11-02    0.546997
# 2016-11-03    0.678184
# 2016-11-04    0.906915
# 2016-11-05    0.435407
# 2016-11-06    0.888889
# 2016-11-07    0.024839
# 2016-11-08    0.378495
# 2016-11-09    0.988407
# 2016-11-10    0.674804
# 2016-11-11    0.499381
# 2016-11-12    0.214949
# 2016-11-13    0.817743
# 2016-11-14    0.973019
# 2016-11-15    0.339988
# 2016-11-16    0.452510
# 2016-11-17    0.540190
# 2016-11-18    0.400143
# 2016-11-19    0.158327
# 2016-11-20    0.933115
# 2016-11-21    0.801445
# 2016-11-22    0.231147
# 2016-11-23    0.060826
# 2016-11-24    0.566106
# 2016-11-25    0.466734
# 2016-11-26    0.146140
# 2016-11-27    0.081894
# 2016-11-28    0.456247
# 2016-11-29    0.652018
# 2016-11-30    0.684771
# Freq: D, dtype: float64

# %%
s["2016-11"].mean()
# Out:
# 0.5271145000190123

# %%
s_month = s.resample("m")
s_month.mean()
# Out:
# 2016-10-31    0.508809
# 2016-11-30    0.527115
# 2016-12-31    0.594515
# Freq: M, dtype: float64

# %%
s_hour = s.resample("H")
s_hour.bfill()
# Out:
# 2016-10-01 00:00:00    0.164638
# 2016-10-01 01:00:00    0.374435
# 2016-10-01 02:00:00    0.374435
# 2016-10-01 03:00:00    0.374435
# 2016-10-01 04:00:00    0.374435
# 2016-10-01 05:00:00    0.374435
# 2016-10-01 06:00:00    0.374435
# 2016-10-01 07:00:00    0.374435
# 2016-10-01 08:00:00    0.374435
# 2016-10-01 09:00:00    0.374435
# 2016-10-01 10:00:00    0.374435
# 2016-10-01 11:00:00    0.374435
# 2016-10-01 12:00:00    0.374435
# 2016-10-01 13:00:00    0.374435
# 2016-10-01 14:00:00    0.374435
# 2016-10-01 15:00:00    0.374435
# 2016-10-01 16:00:00    0.374435
# 2016-10-01 17:00:00    0.374435
# 2016-10-01 18:00:00    0.374435
# 2016-10-01 19:00:00    0.374435
# 2016-10-01 20:00:00    0.374435
# 2016-10-01 21:00:00    0.374435
# 2016-10-01 22:00:00    0.374435
# 2016-10-01 23:00:00    0.374435
# 2016-10-02 00:00:00    0.374435
# 2016-10-02 01:00:00    0.476870
# 2016-10-02 02:00:00    0.476870
# 2016-10-02 03:00:00    0.476870
# 2016-10-02 04:00:00    0.476870
# ...

# %%
s.plot()
# %matplotlib inline
s.plot()

# %%
s_month.plot()
# Out:
# 2016-10-31    AxesSubplot(0.125,0.125;0.775x0.755)
# 2016-11-30    AxesSubplot(0.125,0.125;0.775x0.755)
# 2016-12-31    AxesSubplot(0.125,0.125;0.775x0.755)
# Freq: M, dtype: object
