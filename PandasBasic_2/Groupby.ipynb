# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
# !ls
# Out:
# Binning.ipynb                  Large_sample2.csv
# Groupby.ipynb                  MathOfSeriesAndDataFrame.ipynb

# %%
df = pd.read_csv("Large_sample2.csv")
df
# Out:
#                                   Region                 Country  \
# 0                     Sub-Saharan Africa                 Namibia
# 1                                 Europe                 Iceland
# 2                                 Europe                  Russia
# 3                                 Europe                Moldova
# 4                                 Europe                   Malta
# 5                                   Asia               Indonesia
# 6                     Sub-Saharan Africa                Djibouti
# 7                                 Europe                  Greece
# 8                     Sub-Saharan Africa                Cameroon
# 9                     Sub-Saharan Africa                 Nigeria
# 10                    Sub-Saharan Africa                 Senegal
# 11          Middle East and North Africa             Afghanistan
# 12                                  Asia                   India
# ...

# %%
by_Region = df.groupby(df["Region"])
by_Region.groups
# Out:
# {'Asia': Int64Index([    5,    12,    32,    64,    68,    76,    86,    89,    92,
#                 99,
#              ...
#              49929, 49945, 49950, 49965, 49974, 49975, 49980, 49983, 49988,
#              49997],
#             dtype='int64', length=7348),
#  'Australia and Oceania': Int64Index([   31,    42,    51,    54,    73,    78,    84,    85,    88,
#                 90,
#              ...
#              49858, 49879, 49886, 49890, 49898, 49908, 49919, 49927, 49981,
#              49993],
#             dtype='int64', length=4017),
#  'Central America and the Caribbean': Int64Index([   20,    23,    24,    25,    34,    40,    45,    62,    66,
#                 67,
#              ...
#              49896, 49907, 49914, 49918, 49924, 49972, 49978, 49986, 49995,
#              49996],
#             dtype='int64', length=5451),
#  'Europe': Int64Index([    1,     2,     3,     4,     7,    17,    18,    22,    33,
#                 35,
#              ...
# ...

# %%
by_Region = df.groupby(df["Region"])
type(by_Region.groups)
# Out:
# dict

# %%
by_Region.get_group("North America")
# Out:
#               Region                   Country        Item Type Sales Channel  \
# 59     North America                 Greenland    Personal Care        Online
# 70     North America  United States of America             Meat       Offline
# 107    North America                    Canada           Snacks       Offline
# 111    North America                    Mexico          Clothes        Online
# 161    North America                 Greenland       Vegetables       Offline
# 176    North America  United States of America           Cereal        Online
# 206    North America  United States of America       Vegetables       Offline
# 302    North America                    Canada       Vegetables       Offline
# 320    North America  United States of America    Personal Care        Online
# 330    North America                    Canada        Baby Food        Online
# 371    North America                 Greenland          Clothes        Online
# ...

# %%
by_Region.max()
# Out:
#                                                     Country   Item Type  \
# Region
# Asia                                                Vietnam  Vegetables
# Australia and Oceania                               Vanuatu  Vegetables
# Central America and the Caribbean       Trinidad and Tobago  Vegetables
# Europe                                         Vatican City  Vegetables
# Middle East and North Africa                          Yemen  Vegetables
# North America                      United States of America  Vegetables
# Sub-Saharan Africa                                 Zimbabwe  Vegetables
#
#                                   Sales Channel Order Priority Order Date  \
# Region
# Asia                                     Online              M   9/9/2016
# Australia and Oceania                    Online              M   9/9/2016
# Central America and the Caribbean        Online              M   9/9/2016
# Europe                                   Online              M   9/9/2016
# ...

# %%
for group_name, grout_value in by_Region:
    print(group_name)
    print(grout_value)
# Out:
# Asia
#       Region       Country        Item Type Sales Channel Order Priority  \
# 5       Asia     Indonesia             Meat        Online              H
# 12      Asia         India       Vegetables        Online              C
# 32      Asia   South Korea           Cereal       Offline              H
# 64      Asia    Kazakhstan        Household       Offline              H
# 68      Asia      Mongolia  Office Supplies        Online              M
# 76      Asia      Malaysia          Clothes       Offline              M
# 86      Asia     Singapore             Meat       Offline              C
# 89      Asia        Brunei        Household        Online              M
# 92      Asia    Kyrgyzstan    Personal Care       Offline              H
# 99      Asia        Taiwan        Baby Food       Offline              H
# 118     Asia    Kazakhstan        Baby Food        Online              M
# 124     Asia     Sri Lanka  Office Supplies        Online              L
# ...
