# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
# !ls
# Out:
# DataFrame Introduction.ipynb
# DataFrameIO.ipynb
# Large_sampl2.csv
# Large_sample.csv
# Series Introduction.ipynb
# TheRelationshipBetweenSeriesAndDataFrame.ipynb
# Untitled.ipynb
# df_io.csv
# df_io.html
# sample1.xls

# %%
df = pd.read_csv("Large_sample2.csv")

# %%
df.shape
# Out:
# (50000, 14)

# %% [markdown]
# # Head and Tail

# %%
df.head(5)
# don't print everything.
# Out:
#                Region   Country  Item Type Sales Channel Order Priority  \
# 0  Sub-Saharan Africa   Namibia  Household       Offline              M
# 1              Europe   Iceland  Baby Food        Online              H
# 2              Europe    Russia       Meat        Online              L
# 3              Europe  Moldova        Meat        Online              L
# 4              Europe     Malta     Cereal        Online              M
#
#    Order Date   Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# 0   8/31/2015  897751939  10/12/2015        3604      668.27     502.54
# 1  11/20/2010  599480426    1/9/2011        8435      255.28     159.42
# 2   6/22/2017  538911855   6/25/2017        4848      421.89     364.69
# 3   2/28/2012  459845054   3/20/2012        7225      421.89     364.69
# 4   8/12/2010  626391351   9/13/2010        1975      205.70     117.11
#
#    Total Revenue  Total Cost  Total Profit
# 0     2408445.08  1811154.16     597290.92
# ...

# %%
df.tail(5)
# Out:
#                                   Region             Country        Item Type  \
# 49995  Central America and the Caribbean  Dominican Republic        Baby Food
# 49996  Central America and the Caribbean                Cuba  Office Supplies
# 49997                               Asia             Vietnam    Personal Care
# 49998                 Sub-Saharan Africa        Sierra Leone          Clothes
# 49999                 Sub-Saharan Africa             Eritrea       Vegetables
#
#       Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 49995       Offline              C   2/12/2015  350891578   3/15/2015
# 49996        Online              M   3/28/2013  748260629    5/3/2013
# 49997       Offline              L  11/11/2016  322932231  12/18/2016
# 49998        Online              M   8/28/2010  492142713   9/21/2010
# 49999       Offline              L    6/5/2014  943440902   6/30/2014
#
#        Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# ...

# %% [markdown]
# # Filter columns

# %%
df[["Country", "Region"]]
# Out:
#                       Country                             Region
# 0                     Namibia                 Sub-Saharan Africa
# 1                     Iceland                             Europe
# 2                      Russia                             Europe
# 3                    Moldova                              Europe
# 4                       Malta                             Europe
# 5                   Indonesia                               Asia
# 6                    Djibouti                 Sub-Saharan Africa
# 7                      Greece                             Europe
# 8                    Cameroon                 Sub-Saharan Africa
# 9                     Nigeria                 Sub-Saharan Africa
# 10                    Senegal                 Sub-Saharan Africa
# 11                Afghanistan       Middle East and North Africa
# 12                      India                               Asia
# ...

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %% [markdown]
# # Filter by Position

# %%
df.iloc[0]
# type(df.iloc[0]) / pandas.core.series.Series
# df.head(5)
# Out:
# Region            Sub-Saharan Africa
# Country                      Namibia
# Item Type                  Household
# Sales Channel                Offline
# Order Priority                     M
# Order Date                 8/31/2015
# Order ID                   897751939
# Ship Date                 10/12/2015
# Units Sold                      3604
# Unit Price                    668.27
# Unit Cost                     502.54
# Total Revenue            2.40845e+06
# Total Cost               1.81115e+06
# Total Profit                  597291
# Name: 0, dtype: object

# %%
df.head(3)
# Out:
#                Region  Country  Item Type Sales Channel Order Priority  \
# 0  Sub-Saharan Africa  Namibia  Household       Offline              M
# 1              Europe  Iceland  Baby Food        Online              H
# 2              Europe   Russia       Meat        Online              L
#
#    Order Date   Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# 0   8/31/2015  897751939  10/12/2015        3604      668.27     502.54
# 1  11/20/2010  599480426    1/9/2011        8435      255.28     159.42
# 2   6/22/2017  538911855   6/25/2017        4848      421.89     364.69
#
#    Total Revenue  Total Cost  Total Profit
# 0     2408445.08  1811154.16     597290.92
# 1     2153286.80  1344707.70     808579.10
# 2     2045322.72  1768017.12     277305.60

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df.iloc[:,0:3]
# df.iloc[row_a:row_b, Col_x:col_y]
# Out:
#                                   Region                 Country  \
# 0                     Sub-Saharan Africa                 Namibia
# 1                                 Europe                 Iceland
# 2                                 Europe                  Russia
# 3                                 Europe                Moldova
# 4                                 Europe                   Malta
# 5                                   Asia               Indonesia
# 6                     Sub-Saharan Africa                Djibouti
# 7                                 Europe                  Greece
# 8                     Sub-Saharan Africa                Cameroon
# 9                     Sub-Saharan Africa                 Nigeria
# 10                    Sub-Saharan Africa                 Senegal
# 11          Middle East and North Africa             Afghanistan
# 12                                  Asia                   India
# ...

# %% [markdown]
# # Filter by Label

# %%
df.loc[0:3, ["Country", "Item Type", "Region"]]
# Out:
#     Country  Item Type              Region
# 0   Namibia  Household  Sub-Saharan Africa
# 1   Iceland  Baby Food              Europe
# 2    Russia       Meat              Europe
# 3  Moldova        Meat              Europe
